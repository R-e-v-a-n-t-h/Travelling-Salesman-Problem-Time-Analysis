# %%
df= read.table("/content/TSPtimeData.csv",sep=',',header = TRUE)
df[1]=NULL
df
# Out:
#    N  NaiveTSPtime DynamicTSPtime BranchAndBoundTSPtime BacktrackTSPtime
# 1   3       88504     91163            86829                   11384
# 2   4      182789    147656           125083                   27856
# 3   5       79740    172471           263584                   70952
# 4   6      169583    315734           223843                  304330
# 5   7      743231    659400          1237690                 1802900
# 6   8     7167656   7674893          4109061                17952274
# 7   9    59410238   3711512         17277390               131162753
# 8  10   468400471   9680038         39174294              1054211504
# 9  11  4996426962  24774366         31912830             10802972719
# 10 12 58419026272  89069132       1111469244            122847699294

# %%
#Without manually Analyzing the data values let's assume Naive approach is the slowest method to solve TSP. To test this hypothesis we use a t-test

# %%
t.test(df$NaiveTSPtime, df$DynamicTSPtime,paired = TRUE)
# Out:
# 	Paired t-test
#
# data:  df$NaiveTSPtime and df$DynamicTSPtime
# t = 1.1016, df = 9, p-value = 0.2992
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -6722654545 19485734361
# sample estimates:
# mean of the differences
#              6381539908

# %%
#1 Naive approach is slower than Dyanamic Programming

# %%
t.test(df$NaiveTSPtime, df$BranchAndBoundTSPtime,paired = TRUE)
# Out:
# 	Paired t-test
#
# data:  df$NaiveTSPtime and df$BranchAndBoundTSPtime
# t = 1.1025, df = 9, p-value = 0.2989
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -6600263513 19149426632
# sample estimates:
# mean of the differences
#              6274581560

# %%
#2 Naive approach is slower than Branch and Bound

# %%
t.test(df$NaiveTSPtime, df$BacktrackTSPtime,paired = TRUE)
# Out:
# 	Paired t-test
#
# data:  df$NaiveTSPtime and df$BacktrackTSPtime
# t = -1.1085, df = 9, p-value = 0.2964
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -21560348431   7379444327
# sample estimates:
# mean of the differences
#             -7090452052

# %%
#3 Naive approach is faster compared to backtracking

#So assumption was wrong. We realize that Backtracking is the slowest approach

# %%
plot(df$N,df$NaiveTSPtime,type="o",col="red",lwd=2.0, xlab = "Number of nodes", ylab="Time taken (ns)")
axis(side=1, at=3:12)
lines(df$N,df$DynamicTSPtime,type = "o",col="darkgreen",add=TRUE,lwd=2.0)
lines(df$N,df$BranchAndBoundTSPtime,type = "o",col="blue",add=TRUE,,lwd=2.0)
lines(df$N,df$BacktrackTSPtime,type = "o",col="black",add=TRUE,lwd=2.0)
legend("topleft", legend = c("Greedy Approach", "Dynammic Programming","Branch and Bound","Backtracking"),
       col = c("red","darkgreen","blue","black"), 
       lwd = 4)
# Out:
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"add" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"add" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"add" is not a graphical parameter”
# plot without title

# %%
#From the graph too we analyze Backtracking is the slowest method and the second slowest is naive approach.
#Let's take a closer look at the other two which seem to be faster

# %%
plot(df$N,df$DynamicTSPtime,type = "o",col="darkgreen",lwd=2.0, xlab = "Number of nodes", ylab="Time taken (ns)")
axis(side=1, at=3:12)
lines(df$N,df$BranchAndBoundTSPtime,type = "o",col="blue",add=TRUE,lwd=2.0)

legend("topleft", legend = c("Dynammic Programming","Branch and Bound"),
       col = c("darkgreen","blue"), 
       lwd = 4)
# Out:
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"add" is not a graphical parameter”
# plot without title

# %%
#From the graphs we analyze that Dynamic Programming is the fastest way to solve the Travelling Salesman Problem.

# %%
t.test(df$DynamicTSPtime,df$BranchAndBoundTSPtime,paired=TRUE)
# Out:
# 	Paired t-test
#
# data:  df$DynamicTSPtime and df$BranchAndBoundTSPtime
# t = -1.0511, df = 9, p-value = 0.3206
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -337162907  123246211
# sample estimates:
# mean of the differences
#              -106958348

# %%
#By testing it with a t-test also we find that Dynammic programming is faster than branch and bound
