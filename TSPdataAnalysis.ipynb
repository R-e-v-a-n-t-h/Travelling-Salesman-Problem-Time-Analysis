# %%
df= read.table("/content/TSPtimeData.csv",sep=',',header = TRUE)
df[1]=NULL
df
# Out:
#    N  GreedyTSPtime DynamicTSPtime BranchAndBoundTSPtime BactrackTSPtime
# 1   3       41000      50900           47900                    7400
# 2   4       22900      96000          956700                    8900
# 3   5       59100     105000          103700                   41000
# 4   6       87400     177700          398800                  151100
# 5   7      452600     381000          230100                  911200
# 6   8     2887700     994600          920200                 6374900
# 7   9    29645500    4080300         3690200                49866500
# 8  10   239350500    5464800        32544200               495057700
# 9  11  2848791000   12073900        22417700              5387322500
# 10 12 34543578000   50251500       452681700             64829084900

# %%
#Without manually Analyzing the data values let's assume Greedy approach is the slowest method to solve TSP. To test this hypothesis we use a t-test

# %%
t.test(df$GreedyTSPtime, df$DynamicTSPtime,paired = TRUE)
# Out:
# 	Paired t-test
#
# data:  df$GreedyTSPtime and df$DynamicTSPtime
# t = 1.0971, df = 9, p-value = 0.3011
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3991792795 11510040795
# sample estimates:
# mean of the differences
#              3759124000

# %%
#1 Greedy approach is slower than Dyanamic Programming

# %%
t.test(df$GreedyTSPtime, df$BranchAndBoundTSPtime,paired = TRUE)
# Out:
# 	Paired t-test
#
# data:  df$GreedyTSPtime and df$BranchAndBoundTSPtime
# t = 1.097, df = 9, p-value = 0.3011
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3945879139 11376064039
# sample estimates:
# mean of the differences
#              3715092450

# %%
#2 Greedy approach is slower than Branch and Bound

# %%
t.test(df$GreedyTSPtime, df$BactrackTSPtime,paired = TRUE)
# Out:
# 	Paired t-test
#
# data:  df$GreedyTSPtime and df$BactrackTSPtime
# t = -1.1007, df = 9, p-value = 0.2996
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10114162692   3493380612
# sample estimates:
# mean of the differences
#             -3310391040

# %%
#3 Greedy approach is faster compared to backtracking

#So assumption was wrong. We realize that Backtracking is the slowest approach

# %%
plot(df$N,df$GreedyTSPtime,type="o",col="red",lwd=2.0, xlab = "Number of nodes", ylab="Time taken (ns)")
axis(side=1, at=3:12)
lines(df$N,df$DynamicTSPtime,type = "o",col="darkgreen",add=TRUE,lwd=2.0)
lines(df$N,df$BranchAndBoundTSPtime,type = "o",col="blue",add=TRUE,,lwd=2.0)
lines(df$N,df$BactrackTSPtime,type = "o",col="black",add=TRUE,lwd=2.0)
legend("topleft", legend = c("Greedy Approach", "Dynammic Programming","Branch and Bound","Backtracking"),
       col = c("red","darkgreen","blue","black"), 
       lwd = 4)
# Out:
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"add" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"add" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"add" is not a graphical parameter”
# plot without title

# %%
#From the graph too we analyze Backtracking is the slowest method and the second slowest is greedy approach.
#Let's take a closer look at the other two which seem to be faster

# %%
plot(df$N,df$DynamicTSPtime,type = "o",col="darkgreen",lwd=2.0, xlab = "Number of nodes", ylab="Time taken (ns)")
axis(side=1, at=3:12)
lines(df$N,df$BranchAndBoundTSPtime,type = "o",col="blue",add=TRUE,lwd=2.0)

legend("topleft", legend = c("Dynammic Programming","Branch and Bound"),
       col = c("darkgreen","blue"), 
       lwd = 4)
# Out:
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"add" is not a graphical parameter”
# plot without title

# %%
#From the graphs we analyze that Dynamic Programming is the fastest way to solve the Travelling Salesman Problem.
